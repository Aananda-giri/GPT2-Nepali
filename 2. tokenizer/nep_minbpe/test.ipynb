# %%
def get_devanagari_characters():
    start_char = 'ऀ'
    start_unicode = ord(start_char)  #2304 (unicode codepoint)Integer representation of 'ऀ'  # 0x0900

    end_char = 'ॿ'
    end_unicode = ord(end_char)      # 2431 Hex representation of 'ॿ'

    # print(f"Start Unicode: 0x{start_unicode:04X}")  # 0x0900
    # print(f"End Unicode: 0x{end_unicode:04X}")      # 0x097F
    characters = []
    # Iterate over the range of Devanagari characters (U+0900 to U+097F)
    for codepoint in range(0x0900, 0x0980):
        characters.append(chr(codepoint))
    return characters

devanagari_characters = get_devanagari_characters()
# devanagari_characters
len(devanagari_characters)

# %%
devanagari_characters = get_devanagari_characters()
punctuation = string.punctuation
allowed_characters = devanagari_characters + [char for char in punctuation]
allowed_characters
# Out:
# ['ऀ',
#  'ँ',
#  'ं',
#  'ः',
#  'ऄ',
#  'अ',
#  'आ',
#  'इ',
#  'ई',
#  'उ',
#  'ऊ',
#  'ऋ',
#  'ऌ',
#  'ऍ',
#  'ऎ',
#  'ए',
#  'ऐ',
#  'ऑ',
#  'ऒ',
#  'ओ',
#  'औ',
#  'क',
#  'ख',
#  'ग',
#  'घ',
#  'ङ',
#  'च',
#  'छ',
#  'ज',
#  'झ',
#  'ञ',
#  'ट',
#  'ठ',
#  'ड',
#  'ढ',
#  'ण',
#  'त',
#  'थ',
#  'द',
#  'ध',
#  'न',
#  'ऩ',
#  'प',
#  'फ',
#  'ब',
#  'भ',
#  'म',
#  'य',
#  'र',
#  'ऱ',
#  'ल',
#  'ळ',
#  'ऴ',
#  'व',
#  'श',
#  'ष',
#  'स',
#  'ह',
#  'ऺ',
#  'ऻ',
#  '़',
#  'ऽ',
#  'ा',
#  'ि',
#  'ी',
#  'ु',
#  'ू',
#  'ृ',
#  'ॄ',
#  'ॅ',
#  'ॆ',
#  'े',
#  'ै',
#  'ॉ',
#  'ॊ',
#  'ो',
#  'ौ',
#  '्',
#  'ॎ',
#  'ॏ',
#  'ॐ',
#  '॑',
#  '॒',
#  '॓',
#  '॔',
#  'ॕ',
#  'ॖ',
#  'ॗ',
#  'क़',
#  'ख़',
#  'ग़',
#  'ज़',
#  'ड़',
#  'ढ़',
#  'फ़',
#  'य़',
#  'ॠ',
#  'ॡ',
#  'ॢ',
#  'ॣ',
#  '।',
#  '॥',
#  '०',
#  '१',
#  '२',
#  '३',
#  '४',
#  '५',
#  '६',
#  '७',
#  '८',
#  '९',
#  '॰',
#  'ॱ',
#  'ॲ',
#  'ॳ',
#  'ॴ',
#  'ॵ',
#  'ॶ',
#  'ॷ',
#  'ॸ',
#  'ॹ',
#  'ॺ',
#  'ॻ',
#  'ॼ',
#  'ॽ',
#  'ॾ',
#  'ॿ',
#  '!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
print(len(devanagari_characters))
len(allowed_characters)
# Out:
# 128
# 160

# %%
ord('ॿ')
# Out:
# 2431

# %%
{idx: character for idx,character in enumerate(allowed_characters)}  # int -> character
# Out:
# {0: 'ऀ',
#  1: 'ँ',
#  2: 'ं',
#  3: 'ः',
#  4: 'ऄ',
#  5: 'अ',
#  6: 'आ',
#  7: 'इ',
#  8: 'ई',
#  9: 'उ',
#  10: 'ऊ',
#  11: 'ऋ',
#  12: 'ऌ',
#  13: 'ऍ',
#  14: 'ऎ',
#  15: 'ए',
#  16: 'ऐ',
#  17: 'ऑ',
#  18: 'ऒ',
#  19: 'ओ',
#  20: 'औ',
#  21: 'क',
#  22: 'ख',
#  23: 'ग',
#  24: 'घ',
#  25: 'ङ',
#  26: 'च',
#  27: 'छ',
#  28: 'ज',
#  29: 'झ',
#  30: 'ञ',
#  31: 'ट',
#  32: 'ठ',
#  33: 'ड',
#  34: 'ढ',
#  35: 'ण',
#  36: 'त',
#  37: 'थ',
#  38: 'द',
#  39: 'ध',
#  40: 'न',
#  41: 'ऩ',
#  42: 'प',
#  43: 'फ',
#  44: 'ब',
#  45: 'भ',
#  46: 'म',
#  47: 'य',
#  48: 'र',
#  49: 'ऱ',
#  50: 'ल',
#  51: 'ळ',
#  52: 'ऴ',
#  53: 'व',
#  54: 'श',
#  55: 'ष',
#  56: 'स',
#  57: 'ह',
#  58: 'ऺ',
#  59: 'ऻ',
#  60: '़',
#  61: 'ऽ',
#  62: 'ा',
#  63: 'ि',
#  64: 'ी',
#  65: 'ु',
#  66: 'ू',
#  67: 'ृ',
#  68: 'ॄ',
#  69: 'ॅ',
#  70: 'ॆ',
#  71: 'े',
#  72: 'ै',
#  73: 'ॉ',
#  74: 'ॊ',
#  75: 'ो',
#  76: 'ौ',
#  77: '्',
#  78: 'ॎ',
#  79: 'ॏ',
#  80: 'ॐ',
#  81: '॑',
#  82: '॒',
#  83: '॓',
#  84: '॔',
#  85: 'ॕ',
#  86: 'ॖ',
#  87: 'ॗ',
#  88: 'क़',
#  89: 'ख़',
#  90: 'ग़',
#  91: 'ज़',
#  92: 'ड़',
#  93: 'ढ़',
#  94: 'फ़',
#  95: 'य़',
#  96: 'ॠ',
#  97: 'ॡ',
#  98: 'ॢ',
#  99: 'ॣ',
#  100: '।',
#  101: '॥',
#  102: '०',
#  103: '१',
#  104: '२',
#  105: '३',
#  106: '४',
#  107: '५',
#  108: '६',
#  109: '७',
#  110: '८',
#  111: '९',
#  112: '॰',
#  113: 'ॱ',
#  114: 'ॲ',
#  115: 'ॳ',
#  116: 'ॴ',
#  117: 'ॵ',
#  118: 'ॶ',
#  119: 'ॷ',
#  120: 'ॸ',
#  121: 'ॹ',
#  122: 'ॺ',
#  123: 'ॻ',
#  124: 'ॼ',
#  125: 'ॽ',
#  126: 'ॾ',
#  127: 'ॿ',
#  128: '!',
#  129: '"',
#  130: '#',
#  131: '$',
#  132: '%',
#  133: '&',
#  134: "'",
#  135: '(',
#  136: ')',
#  137: '*',
#  138: '+',
#  139: ',',
#  140: '-',
#  141: '.',
#  142: '/',
#  143: ':',
#  144: ';',
#  145: '<',
#  146: '=',
#  147: '>',
#  148: '?',
#  149: '@',
#  150: '[',
#  151: '\\',
#  152: ']',
#  153: '^',
#  154: '_',
#  155: '`',
#  156: '{',
#  157: '|',
#  158: '}',
#  159: '~'}
